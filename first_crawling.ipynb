# %%
# %pip install beautifulsoup4
# %pip install requests
# Out:
# Requirement already satisfied: beautifulsoup4 in c:\users\chung\anaconda3\lib\site-packages (4.9.3)
# Requirement already satisfied: soupsieve>1.2; python_version >= "3.0" in c:\users\chung\anaconda3\lib\site-packages (from beautifulsoup4) (2.0.1)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: requests in c:\users\chung\anaconda3\lib\site-packages (2.24.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\chung\anaconda3\lib\site-packages (from requests) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\chung\anaconda3\lib\site-packages (from requests) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\chung\anaconda3\lib\site-packages (from requests) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\chung\anaconda3\lib\site-packages (from requests) (3.0.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
1+1
# Out:
# 2

# %%
import requests
from bs4 import BeautifulSoup as bs

page = requests.get("https://library.gabia.com/")
soup = bs(page.text, "html.parser")

elements = soup.select('div.esg-entry-content a > span')

for index, element in enumerate(elements, 1):
		print("{} 번째 게시글의 제목: {}".format(index, element.text))
# Out:
# 1 번째 게시글의 제목: “100만 원 드립니다” 전자세금계산서 세액 공제 알아보기
# 2 번째 게시글의 제목: 클라우드 컴퓨팅의 종류, DaaS란?
# 3 번째 게시글의 제목: 인터넷 익스플로러 없이 일할 준비, 되셨나요?
# 4 번째 게시글의 제목: 전자세금계산서 의무 발급 대상자가 늘어났다고?
# 5 번째 게시글의 제목: 전자세금계산서의 작성일자는 ‘작성하는 날짜’가 아니다?
# 6 번째 게시글의 제목: 가비아, 2021 클라우드 산업대상 '장관상' 수상
# 7 번째 게시글의 제목: 2022년 가비아 달력 세트 개봉기
# 8 번째 게시글의 제목: 내국신용장이 개설되었다면? 전자세금계산서 수정 발급 4
# 9 번째 게시글의 제목: 2022년 공휴일 총 67일, 직장인이라면 모든 공휴일에 쉴까?
# 10 번째 게시글의 제목: 반품되거나 계약이 취소되었다면? 전자세금계산서 수정 발급 3
# 11 번째 게시글의 제목: 일과 삶을 분리하는 방법, 기업 메신저
# 12 번째 게시글의 제목: 공급가액이 달라졌다면? 전자세금계산서 수정 발급 2
# 13 번째 게시글의 제목: 기업 메일이란? – 정의, 필요성, 도입 방법 알아보기
# 14 번째 게시글의 제목: 실수로 작성일자를 잘못 적었다면? 전자세금계산서 수정 발급 1
# 15 번째 게시글의 제목: 협업 툴이란? - 정의, 장단점 알아보기
# 16 번째 게시글의 제목: 스마트 광고 고객 사례 - 루트임팩트
# 17 번째 게시글의 제목: 전자세금계산서는 취소나 삭제가 불가능하다? 수정 발급 알아보기
# 18 번째 게시글의 제목: 검색 광고 키워드를 선정할 때 인공지능 기술이 중요한 이유
# 19 번째 게시글의 제목: 그룹웨어란? - 정의, 필요성, 종류 알아보기
# 20 번째 게시글의 제목: 전자세금계산서 발급과 전송은 다르다? 가산세 알아보기 2
# 21 번째 게시글의 제목: 기업 담당자가 꼭 알아야 하는 '주 52시간'의 3가지 의미
# 22 번째 게시글의 제목: 전자세금계산서를 늦게 발급했다면? 가산세 알아보기 1
# 23 번째 게시글의 제목: 망하는 조직이 소통하는 방법
# 24 번째 게시글의 제목: 기업이 개인용 메신저를 쓰지 않는 3가지 이유
# 25 번째 게시글의 제목: 스마트 쇼핑 광고 - 판매자 센터 연동하기
# 26 번째 게시글의 제목: 인공 지능 검색 광고에서 브랜드 키워드의 중요성
# 27 번째 게시글의 제목: 전환 추적 태그란? - 개념/장점/방법
# 28 번째 게시글의 제목: 서버호스팅 vs 클라우드 서버 vs 베어메탈 서버 비교
# 29 번째 게시글의 제목: 비즈니스에 최적화 된 서버 선택 방법
# 30 번째 게시글의 제목: 베어메탈 서버(Bare Metal Server)란?
# 31 번째 게시글의 제목: 스마트 검색 광고 소개: 일반 검색 광고와의 차이점
# 32 번째 게시글의 제목: 2021년 그룹웨어 트렌드 전망
# 33 번째 게시글의 제목: 2021년 주요 사이버 보안 위협 예측
# 34 번째 게시글의 제목: 파이썬(Python) 바로 알기 - 특징, 장점, 활용 사례
# 35 번째 게시글의 제목: BeautifulSoup와 requests로 웹 파싱해보기 - 파이썬 실습
# 36 번째 게시글의 제목: ERP 회계경영관리 알아보기
# 37 번째 게시글의 제목: ERP 도입 시 고려사항
# 38 번째 게시글의 제목: 비즈니스에 ERP가 필요한 이유
# 39 번째 게시글의 제목: ERP란? ERP의 개념 및 도입 현황
# 40 번째 게시글의 제목: 언택트 시대의 기업 메일이 중요한 이유
# 41 번째 게시글의 제목: 포스트 코로나 시대의 클라우드
# 42 번째 게시글의 제목: 클라우드 플랫폼과 마이크로서비스
# 43 번째 게시글의 제목: 퍼블릭 클라우드, 프라이빗 클라우드, 하이브리드 클라우드
# 44 번째 게시글의 제목: 클라우드 마이그레이션 전략 알아보기
# 45 번째 게시글의 제목: 클라우드 vs 웹호스팅 vs 서버호스팅 구분
# 46 번째 게시글의 제목: 마이데이터란 무엇인가
# 47 번째 게시글의 제목: 클라우드에 저장된 개인정보, 어떤 문제가 있을까
# 48 번째 게시글의 제목: 클라우드 컴퓨팅의 종류, SaaS란?
# 49 번째 게시글의 제목: 기업이 하이브리드 클라우드를 주목하는 이유
# 50 번째 게시글의 제목: 클라우드란 무엇인가 - 개념, 장점, 서비스 구분
# 51 번째 게시글의 제목: 클라우드 컴퓨팅의 종류, PaaS란?
# 52 번째 게시글의 제목: 클라우드 컴퓨팅의 종류, IaaS란?
# 53 번째 게시글의 제목: 클라우드 DB 암호화 도입/구축 팁
# 54 번째 게시글의 제목: 클라우드 스냅샷이란?
# 55 번째 게시글의 제목: 클라우드 백업이란?
# 56 번째 게시글의 제목: [클라우드 이해] CDN 아키텍처
# 57 번째 게시글의 제목: 클라우드 스토리지 종류(파일/블록/객체 스토리지)
# 58 번째 게시글의 제목: SSH 명칭부터 접속까지 한 번에 이해하기 2
# 59 번째 게시글의 제목: SSH 명칭부터 접속까지 한 번에 이해하기 1
# 60 번째 게시글의 제목: 클라우드 DB 암호화란?
# 61 번째 게시글의 제목: [클라우드 이해] CDN이란?
# 62 번째 게시글의 제목: [클라우드 이해] 스냅샷과 백업의 차이점
# 63 번째 게시글의 제목: AWS 디지털 고객 경험(DCX) 사례- 지나인
# 64 번째 게시글의 제목: AWS 디지털 고객 경험(DCX) 사례- MR.PIC
# 65 번째 게시글의 제목: AWS Elastic File System 알아보기
# 66 번째 게시글의 제목: AWS CloudFront 오류 페이지 설정 (with EC2, S3)
# 67 번째 게시글의 제목: Private Windows 원격 접속 방법(AWS Putty, Linux Bastion EC2)
# 68 번째 게시글의 제목: AWS Time Sync Service 구성
# 69 번째 게시글의 제목: AWS Private Link(with S3)
# 70 번째 게시글의 제목: AWS Network ACL과 Security Group 차이점
# 71 번째 게시글의 제목: Region 간 VPC Peering하기
# 72 번째 게시글의 제목: VPC Flow Logs 알아보기
# 73 번째 게시글의 제목: Amazon DLM으로 EBS 스냅샷 관리 자동화하는 방법
# 74 번째 게시글의 제목: Amazon EBS를 여러 EC2에 연결하는 방법
# 75 번째 게시글의 제목: 국내 그룹웨어사 전자세금계산서 상품 비교하기
# 76 번째 게시글의 제목: 효율적인 계산서 업무 수행하기
# 77 번째 게시글의 제목: [기고] 코로나發 클라우드 패러다임 (1)
# 78 번째 게시글의 제목: [기고] 코로나發 클라우드 패러다임 (2)
# 79 번째 게시글의 제목: 국내 그룹웨어 5개사 비교하기 _부가 서비스/고객 지원편
# 80 번째 게시글의 제목: 국내 그룹웨어 5개사 비교하기_기능편
# 81 번째 게시글의 제목: 국내 그룹웨어 5개사 비교하기_상품/가격편
# 82 번째 게시글의 제목: 슬기로운 유연근무제 정부 지원금 신청하기
# 83 번째 게시글의 제목: 정부 지원금 받는 유연근무제 도입하기
# 84 번째 게시글의 제목: 가비아 클라우드, 고객 충성도 대상 시상식 참가
# 85 번째 게시글의 제목: [재택근무] 재택근무도 예외 없는 근태 관리하기
# 86 번째 게시글의 제목: [재택근무] 집에서도 결재 문서 기안하기
# 87 번째 게시글의 제목: [재택근무] 공간 제약 없는 커뮤니케이션하기
# 88 번째 게시글의 제목: 가비아 프로젝트 팀 TEAMS 소개
# 89 번째 게시글의 제목: husky 로 git hook 하자
# 90 번째 게시글의 제목: [재택근무] 화상회의로 협업하기
# 91 번째 게시글의 제목: [재택근무] 재택근무, 새로운 근무 패러다임의 시대
# 92 번째 게시글의 제목: Laravel에 Modern 하게 DTO 사용하기
# 93 번째 게시글의 제목: 가비아, 2020 브랜드 고객 충성도 대상 수상
# 94 번째 게시글의 제목: 원격근무를 가능케 하는 기술, VPN
# 95 번째 게시글의 제목: [이적X하이웍스] 이적이 알려주는 하이웍스 기능 알아보기
# 96 번째 게시글의 제목: [이적X하이웍스] 광고 촬영 비하인드 스토리 공개
# 97 번째 게시글의 제목: REST API 관점에서 바라보는 HTTP 상태 코드
# 98 번째 게시글의 제목: RESTful API 설계 가이드
# 99 번째 게시글의 제목: PHP와 Node.js 바로 알기
# 100 번째 게시글의 제목: [Node.js] React.js vs Vue.js, 자바스크립트 프레임워크 비교
# 101 번째 게시글의 제목: 하이웍스 그룹웨어 고객사례: 도원회계법인
# 102 번째 게시글의 제목: Non Active X로 만나는 하이웍스 세금계산서
# 103 번째 게시글의 제목: AWS 도입 사례: 캐스트프로
# 104 번째 게시글의 제목: [보안메일] DMARC, 도메인기반이메일인증
# 105 번째 게시글의 제목: [보안메일] DKIM, 도메인키인증메일
# 106 번째 게시글의 제목: [보안메일] SPF, 메일서버등록제
# 107 번째 게시글의 제목: [Node.js] 인기 NPM 패키지 알아보기
# 108 번째 게시글의 제목: 한국 기업의 전자결재 문화 알아보기
# 109 번째 게시글의 제목: [Node.js] Socket.IO와 Redis를  활용한 채팅 서버 개발
# 110 번째 게시글의 제목: [Node.js] 개발 환경 갖추기: 텍스트 에디터 소개
# 111 번째 게시글의 제목: 전자결재 양식 직접 제작하기
# 112 번째 게시글의 제목: 클라우드 보안인증(CSAP) 알아보기
# 113 번째 게시글의 제목: [주52시간] 유연근무제 운영하기
# 114 번째 게시글의 제목: [주52시간] 사전승인으로 연장근로 관리하기
# 115 번째 게시글의 제목: [주52시간] 출퇴근 기록과 근무시간 관리하기
# 116 번째 게시글의 제목: [주52시간] 초과근무수당 계산하기
# 117 번째 게시글의 제목: [가비아 뉴스] 해외 디자이너 초청 강연
# 118 번째 게시글의 제목: [주52시간] 법정근로시간 운영 원칙
# 119 번째 게시글의 제목: [주52시간] 개정 근로기준법 알아보기
# 120 번째 게시글의 제목: [가비아 뉴스] Innovation Solution Day 2019 후기
# 121 번째 게시글의 제목: 기업들 낚는 문자/메일 피싱 사기
# 122 번째 게시글의 제목: [가비아 뉴스] JSConf korea 2019 후기
# 123 번째 게시글의 제목: 스팸 메일의 종류 및 대처 방안
# 124 번째 게시글의 제목: 협업에서 정말 중요한 것
# 125 번째 게시글의 제목: 모니터링, 이제는 선택이 아닌 필수!
# 126 번째 게시글의 제목: 하이웍스 기초 교육 후기
# 127 번째 게시글의 제목: 업무 상황별 효과적인 커뮤니케이션 수단
# 128 번째 게시글의 제목: 코딩 없이 만드는 반응형 홈페이지
# 129 번째 게시글의 제목: 하이웍스 그룹웨어 고객사례: 보그인터내셔날
# 130 번째 게시글의 제목: 하이웍스 API 이용 사례: 그린카
# 131 번째 게시글의 제목: 하이웍스 API 이용 사례: 아이퀘스트
# 132 번째 게시글의 제목: 하이웍스 API 이용 사례: 에스원
# 133 번째 게시글의 제목: 하이웍스 API 이용 사례: 신한은행
# 134 번째 게시글의 제목: 클라우드 퍼스트 시대, 기업의 클라우드 활용 현황은?
# 135 번째 게시글의 제목: Portainer로 도커(Docker) 쉽게 사용하기!
# 136 번째 게시글의 제목: 서버 가상화 기술의 진화: VM과 컨테이너
# 137 번째 게시글의 제목: 하이웍스 그룹웨어 고객사례: 혜민병원
# 138 번째 게시글의 제목: 하이웍스 그룹웨어 고객사례: 천우모터스
# 139 번째 게시글의 제목: 협업 툴이 떠오르는 이유
# 140 번째 게시글의 제목: 하이웍스 서비스 선택 가이드
# 141 번째 게시글의 제목: 왜 멀티 클라우드가 필요한가요?
# 142 번째 게시글의 제목: 승인메일로 메일 발송 실수 줄이기
# 143 번째 게시글의 제목: 무제한 메일로 용량 걱정 없이 기업메일 사용하기
# 144 번째 게시글의 제목: 개인메일보다 기업메일을 사용하면 좋은점
# 145 번째 게시글의 제목: 기업메일 주요 기능 알아보기
# 146 번째 게시글의 제목: 우리 회사에 딱 맞는 기업메일 도입하기
# 147 번째 게시글의 제목: WWW 30주년, 웹은 아직도 열린 공간일까?
# 148 번째 게시글의 제목: 해커에겐 너무나 가벼운 표적, 중소기업
# 149 번째 게시글의 제목: 안전하고 효율적인 백업 전략 세우기
# 150 번째 게시글의 제목: 비즈니스 연속성을 실현하는 '백업' 이해하기
# 151 번째 게시글의 제목: 협업을 위한 성공적인 데브옵스(DevOps) 프로젝트
# 152 번째 게시글의 제목: 클라우드 시대, 엔지니어의 재조명
# 153 번째 게시글의 제목: 하이웍스가 이야기하는 비즈니스 메일의 진화
# 154 번째 게시글의 제목: 가비아 IDC의 핵심, 통합관제센터
# 155 번째 게시글의 제목: 비즈니스에 필요한 IT를 쉽게 시작하는 방법
# 156 번째 게시글의 제목: SaaS 클라우드에 기업 데이터를 믿고 보관해도 될까?
# 157 번째 게시글의 제목: 도메인 등록업체 선정, 이렇게 하세요
# 158 번째 게시글의 제목: 카톡 업무지시를 피하는 기업용 메신저 사용법
# 159 번째 게시글의 제목: 기업의 보안 수준, 어떻게 높일까?
# 160 번째 게시글의 제목: [하이웍스 광고] 이상민의 CF 촬영 비하인드스토리 공개!
# 161 번째 게시글의 제목: 웹사이트에서 주고받는 정보는 어떻게 보호될까?
# 162 번째 게시글의 제목: [특별기고] CPU취약점 종합보고서③: Spectre Variant 2
# 163 번째 게시글의 제목: 리눅스에서 사용하는 MSSQL Server 2017
# 164 번째 게시글의 제목: 마이크로소프트 SPLA의 모든 것
# 165 번째 게시글의 제목: MS SQL Server 2017 라이선스 구매 방법
# 166 번째 게시글의 제목: [특별기고] CPU취약점 종합보고서②: MeltDown과 Spectre Variant 1
# 167 번째 게시글의 제목: [특별기고] CPU 취약점 종합보고서 ①: 취약점 기본원리
# 168 번째 게시글의 제목: 호스팅에서 보안이 점점 더 중요해지는 이유
# 169 번째 게시글의 제목: 피싱 사이트, 제대로 알고 예방하세요!
# 170 번째 게시글의 제목: 개인정보 유출에 대비하는 3가지 방법
# 171 번째 게시글의 제목: PC와 모바일이 악성코드에 감염되는 원리
# 172 번째 게시글의 제목: 인트라넷 보안의 약점은 APT! 대응 방법은?
# 173 번째 게시글의 제목: 업무에 필요한 모든 기능을 담은 하이웍스
# 174 번째 게시글의 제목: 그룹웨어 기능 알아보기: 전자결재
# 175 번째 게시글의 제목: 그룹웨어 기능 알아보기: 게시판
# 176 번째 게시글의 제목: 그룹웨어의 유래
# 177 번째 게시글의 제목: 그룹웨어 보안
# 178 번째 게시글의 제목: 그룹웨어 구축형 VS 임대형
# 179 번째 게시글의 제목: 비트코인, 해킹을 위한 검은 화폐인가 효용성 있는 신개념 화폐인가?
# 180 번째 게시글의 제목: 영화 자막파일에도 랜섬웨어가?
# 181 번째 게시글의 제목: 무시하면 큰일나는 도메인의 과거
# 182 번째 게시글의 제목: 바이러스부터 랜섬웨어까지, 자주 나타나는 악성코드들
# 183 번째 게시글의 제목: 내 홈페이지에 딱 맞는 색깔 고르기 팁
# 184 번째 게시글의 제목: 혹시 내 PC가 바이러스에? 악성코드 감염 징후와 해결법
# 185 번째 게시글의 제목: 도메인에 대한 오해, 무엇이 있을까?
# 186 번째 게시글의 제목: .com 도메인을 얻는 5가지 스마트한 방법
# 187 번째 게시글의 제목: 웹방화벽 쉽게 비교하기
# 188 번째 게시글의 제목: 오피스365와 오피스2016은 어떻게 다를까
# 189 번째 게시글의 제목: 오피스365의 세 종류 – 가정용, 비즈니스용, 엔터프라이즈용
# 190 번째 게시글의 제목: 오피스365, 구매는 어디서?
# 191 번째 게시글의 제목: 2016년 도메인 업계의 새로운 바람, ‘New gTLD’
# 192 번째 게시글의 제목: 리눅스 보안 이슈를 해결하는 4가지 방법
# 193 번째 게시글의 제목: 검색엔진 최적화(SEO), 가장 효율적인 방법은?
# 194 번째 게시글의 제목: 믿을만한 호스팅 업체, 어디 없을까?
# 195 번째 게시글의 제목: 중소기업이 클라우드 도입으로 절약할 수 있는 5가지 비용
# 196 번째 게시글의 제목: DNS 구성 요소 – ③ 존 파일(Zone File)
# 197 번째 게시글의 제목: DNS 구성 요소 - ② 도메인 네임 서버(Domain Name Server)
# 198 번째 게시글의 제목: DNS 구성 요소 - ① 도메인 이름 공간 (Domain Name Space)
# 199 번째 게시글의 제목: 인터넷 발전사로 알아보는 DNS – ④ 전환, 새로운 시스템을 찾아서
# 200 번째 게시글의 제목: 인터넷 발전사로 알아보는 DNS – ③ 네트워크의 확장
# 201 번째 게시글의 제목: 인터넷 발전사로 알아보는 DNS – ② 호스트의 변화
# 202 번째 게시글의 제목: 인터넷 발전사로 알아보는 DNS – ① 최초의 연결
# 203 번째 게시글의 제목: '네임서버 설정'으로 알아보는 DNS: ③ 네임서버 정보는 어디에서 얻을 수 있나
# 204 번째 게시글의 제목: '네임서버 설정'으로 알아보는 DNS: ② IP 주소와 호스트명 알아보기
# 205 번째 게시글의 제목: '네임서버 설정'으로 알아보는 DNS: ① 도메인 등록 페이지에서 DNS 키워드 찾기
# 206 번째 게시글의 제목: DNS 기초 지식 - 컴퓨터의 실체와 작동 원리 下
# 207 번째 게시글의 제목: DNS 기초 지식 - 컴퓨터의 실체와 작동 원리 上
# 208 번째 게시글의 제목: VPS 호스팅 선택 전 이것만 체크하자!
# 209 번째 게시글의 제목: 가상서버(VPS호스팅/클라우드) 비교하기
# 210 번째 게시글의 제목: 가상서버와 물리서버 상세 비교하기
# 211 번째 게시글의 제목: VPS호스팅과 웹호스팅 비교하기
# 212 번째 게시글의 제목: ‘공간’과 ‘비용’으로 알아보는 웹호스팅, VPS, 서버호스팅, 클라우드의 차이점
# 213 번째 게시글의 제목: 쉽게 알아보는 VPS의 정의와 장단점
# 214 번째 게시글의 제목: 알고 보면 쉬운 랜섬웨어 예방법 6가지
# 215 번째 게시글의 제목: [리눅스 서버 구축하기] 7. MySQL 설치
# 216 번째 게시글의 제목: [리눅스 서버 구축하기] 6. DNS 설정
# 217 번째 게시글의 제목: [리눅스 서버 구축하기] 5. php 설치와 설정
# 218 번째 게시글의 제목: [리눅스 서버 구축하기] 4. 아파치 설치 및 설정
# 219 번째 게시글의 제목: [리눅스 서버 구축하기] 3. CentOS 설치 방법
# 220 번째 게시글의 제목: [리눅스 서버 구축하기] 2. 리눅스 배포판의 종류와 특징
# 221 번째 게시글의 제목: [리눅스 서버 구축하기] 1. 기초 지식 알아보기
# 222 번째 게시글의 제목: 클라우드 저장 장치와 P2P 서비스의 차이점
# 223 번째 게시글의 제목: 클라우드 컴퓨팅과 보안 문제
# 224 번째 게시글의 제목: Thin-Client/노하드 시스템이란?
# 225 번째 게시글의 제목: 홈페이지에 꼭 들어가야 하는 필수항목
# 226 번째 게시글의 제목: 도메인 작명의 핵심, 간결성과 대표성
# 227 번째 게시글의 제목: 웹 접근성을 높이는 두 가지 방법
# 228 번째 게시글의 제목: 장벽 없는 홈페이지 만들기 - 웹 접근성이란?
# 229 번째 게시글의 제목: gTLD 분쟁은 어떻게 해결할까
# 230 번째 게시글의 제목: 도메인 분쟁 중재 판정의 결과
# 231 번째 게시글의 제목: 도메인 분쟁의 체크 포인트!
# 232 번째 게시글의 제목: 도메인 분쟁, 중재는 어떻게?
# 233 번째 게시글의 제목: 도메인 분쟁의 배경, 상표권
# 234 번째 게시글의 제목: 포털 사이트의 블로그나 카페에 도메인 연결하는 방법
# 235 번째 게시글의 제목: 도메인, 웹호스팅 업체가 다를 때 홈페이지에 도메인 연결하는 방법
# 236 번째 게시글의 제목: 무료 홈페이지 빌더, WIX 활용법 ③ 관리툴 기능 살펴보기
# 237 번째 게시글의 제목: 무료 홈페이지 빌더, WIX 활용법 ② 도메인 연결하기
# 238 번째 게시글의 제목: 무료 홈페이지 빌더, WIX 활용법 ① 홈페이지 만들기
# 239 번째 게시글의 제목: 도메인에 관해서는 구글보다 똑똑한 WHOIS는 어떻게 생겨났을까?
# 240 번째 게시글의 제목: 도메인 세계의 뜨거운 감자, WHOIS: 정보의 투명한 공개인가 개인정보의 침해인가
# 241 번째 게시글의 제목: ‘어떤 도메인이든’ 검색 가능한 WHOIS는 무엇이며, 어떤 정보가 제공될까?
# 242 번째 게시글의 제목: 업체마다 다른 도메인 등록 비용, 무엇이 진짜일까?
# 243 번째 게시글의 제목: 도메인, 한 번 등록하면 영원히 내 것이 되는 것일까?
# 244 번째 게시글의 제목: 도메인, .com, .net만이 답일까?
# 245 번째 게시글의 제목: 도메인 등록은 어디에서 할 수 있나?
# 246 번째 게시글의 제목: FTP를 이용하는 간단한 웹페이지 업로드
# 247 번째 게시글의 제목: 도메인 활용의 기본, 웹사이트 연결하기
# 248 번째 게시글의 제목: TLD 한 눈에 비교하기
# 249 번째 게시글의 제목: 서버임대? 구매? 클라우드? - 적절한 선택하기
# 250 번째 게시글의 제목: 취약점 패치 및 보안 업데이트의 중요성
# 251 번째 게시글의 제목: 암호화 해야 하는 정보와 저장하면 안 되는 정보
# 252 번째 게시글의 제목: 장벽 없는 홈페이지 만들기 – 웹 표준화
# 253 번째 게시글의 제목: 웹 표준을 준수한 홈페이지의 긍정적 효과
# 254 번째 게시글의 제목: 웹사이트의 꾸준한 관리를 위한 유지보수 서비스
# 255 번째 게시글의 제목: 홈페이지 외주제작의 6단계 프로세스
# 256 번째 게시글의 제목: 홈페이지 제작 외주업체 선정의 3가지 기준
# 257 번째 게시글의 제목: 시간이 부족한 분들을 위한 홈페이지 제작 방법
# 258 번째 게시글의 제목: 홈페이지 제작의 두 가지 방식 – 빌더제작과 맞춤제작
# 259 번째 게시글의 제목: 서버 가상화의 장점 – 유연성
# 260 번째 게시글의 제목: SSL 보안서버 인증서가 필요한 이유
# 261 번째 게시글의 제목: 보안에 투자할 비용을 산정하는 방법
# 262 번째 게시글의 제목: 내 블로그에 새로운 이름을 입히는 방법: 도메인 연결하기
# 263 번째 게시글의 제목: 랙에 네트워크 장비를 설치하는 방법
# 264 번째 게시글의 제목: 랙에 서버를 설치하는 방법
# 265 번째 게시글의 제목: 서비스에 따라 달라지는 IDC의 위치
# 266 번째 게시글의 제목: IDC 설계의 핵심, 전원체계 들여다보기
# 267 번째 게시글의 제목: IDC에는 케이지가 있다?
# 268 번째 게시글의 제목: Percona Xtradb 이용한 MySQL클러스터
# 269 번째 게시글의 제목: 내가 등록한 도메인을 팔 수는 없나?
# 270 번째 게시글의 제목: 도메인 중개 사이트에 등록된 매물 구매하기
# 271 번째 게시글의 제목: 도메인 이름 직거래는 이렇게!
# 272 번째 게시글의 제목: 등록된 도메인, 살 수는 없을까?
# 273 번째 게시글의 제목: 클라우드 컴퓨팅 서비스의 종류
# 274 번째 게시글의 제목: 클라우드 컴퓨팅의 다섯 가지 조건
# 275 번째 게시글의 제목: 인구, 소득, 도메인의 상관관계
# 276 번째 게시글의 제목: 가상화의 세 가지 방식
# 277 번째 게시글의 제목: 세계 최초의 도메인은 무엇일까?
# 278 번째 게시글의 제목: 윈도우95에서 시작된 2차 도메인 전성기
# 279 번째 게시글의 제목: 최초의 도메인과 함께 보는 1단계 도메인의 탄생
# 280 번째 게시글의 제목: 홀쭉한 도메인 정보와 뚱뚱한 도메인 정보
# 281 번째 게시글의 제목: 도메인 이전에 대해 자주 하는 질문들
# 282 번째 게시글의 제목: 호스팅 업체와의 컨설팅 과정에서 받을 수 있는 질문들
# 283 번째 게시글의 제목: IDC 서비스 컨설팅, 왜 필요한가?
# 284 번째 게시글의 제목: 도메인 소유권 이전 절차의 유의 사항
# 285 번째 게시글의 제목: 안전한 웹서비스를 위한 두 가지 웹 방화벽
# 286 번째 게시글의 제목: 도메인 소유권 이전의 정의와 제한
# 287 번째 게시글의 제목: 도메인 기관이전 절차의 A to Z
# 288 번째 게시글의 제목: 리눅스 운영체제 iptables에 기반한 방화벽 설정 방법
# 289 번째 게시글의 제목: 기관이전 제한은 없나? 사전 확인부터 꼼꼼하게!
# 290 번째 게시글의 제목: 기관 이전과 소유권 이전의 차이점
# 291 번째 게시글의 제목: 함부로 못 바꾸는 도메인 정보는?
# 292 번째 게시글의 제목: 네트워크를 지키는 요새, 네트워크 방화벽의 역할
# 293 번째 게시글의 제목: 먼저 결제한 사람이 도메인의 주인이 된다
# 294 번째 게시글의 제목: 놓치면 큰일나는 도메인 등록 필수 정보!
# 295 번째 게시글의 제목: 웹사이트 제작의 첫 걸음, 도메인
# 296 번째 게시글의 제목: 가비아가 IDC에서 사용하는 4개의 회선
# 297 번째 게시글의 제목: V-IDC 사업자와 계약했을 때의 장점
# 298 번째 게시글의 제목: 가비아 IDC 통합관제센터
# 299 번째 게시글의 제목: [가비아 리브랜딩 프로젝트 전시회] Beyond the web
# 300 번째 게시글의 제목: [가비아 CI 리뉴얼] 점, 네트워크, 그리고 선
# 301 번째 게시글의 제목: 좋은 도메인 고르는 TIP
# 302 번째 게시글의 제목: 웹호스팅 / 서버호스팅 / 클라우드 차이점은?
# 303 번째 게시글의 제목: [인프라 용어 알아보기] 제 3탄: 디스크(DISK) – 용량, 회전수, 버퍼 용량, 크기, 인터페이스, A/S 보증기간
# 304 번째 게시글의 제목: [인프라 용어 알아보기] 제 2탄: 메모리(RAM) – 종류, 용량, 동작 클럭, 슬롯, ECC
# 305 번째 게시글의 제목: [인프라 용어 알아보기] 제 1탄: CPU – 제조공정, 클럭, 코어, 스레드, 캐시 메모리
# 306 번째 게시글의 제목: 서버 확장을 위한 두 가지 방법: 스케일 아웃과 스케일 업
# 307 번째 게시글의 제목: 서버 선택 시, 이것만은 꼭 확인하세요!
# 308 번째 게시글의 제목: 호스팅 한 눈에 비교하기
# 309 번째 게시글의 제목: 도메인, 등록보다 중요한 것은 보안!
# 310 번째 게시글의 제목: 도메인이 전한 코카콜라의 61가지 이야기
# 311 번째 게시글의 제목: 홈페이지, 비워두지 마세요: 도메인 파킹 활용하기
# 312 번째 게시글의 제목: 포털 메일 대신 도메인 메일을 쓰는 것이 좋은 세 가지 이유!
# 313 번째 게시글의 제목: '도메인 포워딩 서비스'를 이용하여 내 홈페이지의 접속 통로 넓히기
# 314 번째 게시글의 제목: 서버와 일반 컴퓨터, 무엇이 다를까?
# 315 번째 게시글의 제목: KR로 대표되는 ‘ccTLD’의 등록 주기는 어떻게 될까?
# 316 번째 게시글의 제목: COM, NET으로 대표되는 ‘gTLD’의 등록 주기는 어떻게 될까?
# 317 번째 게시글의 제목: 도메인, 영원한 소유는 없다! '도메인 라이프 사이클' 알아보기
# 318 번째 게시글의 제목: 도메인에도 '단계'가 있다!
# 319 번째 게시글의 제목: 익숙한 듯, 익숙하지 않은 'TLD'란 무엇일까?
# 320 번째 게시글의 제목: 도메인이란?

# %%
import requests
from bs4 import BeautifulSoup as bs

page = requests.get("https://sports.news.naver.com/index")
soup = bs(page.text, "html.parser")

elements = soup.select('a > div.text_area > strong')
for index, element in enumerate(elements, 1):
		print("{} 번째 게시글의 제목: {}".format(index, element.text))
# Out:
# 1 번째 게시글의 제목: "3:0이면 손흥민에게 PK 양보? " 질문에…케인은 '머쓱한 미소'
# 2 번째 게시글의 제목: "미국 떠나 한국까지 왔는데"…그가 자주 분노하는 이유
# 3 번째 게시글의 제목: 콘테 눈도장 제대로 찍었다… UEL 결승 맹활약 '최고 영입' 기대감
# 4 번째 게시글의 제목: 데이원자산운용, 농구단 초대 사령탑에 김승기 감독 내정
# 5 번째 게시글의 제목: 1년 전 축구계 홀렸던 '203cm' 골잡이, 팬 앞 설렁설렁 '뛸 의지'가 없다
# 6 번째 게시글의 제목: '천재 국대' 드디어 돌아온다, 무서운 회복 속도→예상마저 뒤집었다
